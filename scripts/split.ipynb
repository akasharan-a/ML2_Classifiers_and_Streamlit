# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('../data/Industrial Fabric Quality Inspection Dataset.csv')
df.head()
# Out:
#    thread_count    gsm  tensile_strength  shrinkage_percent  color_fastness  \
# 0         166.0  383.0               NaN           7.744704               1
# 1         273.0  107.0        106.508682           1.191272               1
# 2         274.0  352.0         97.100410                NaN               3
# 3           NaN  200.0         17.876660           4.001214               1
# 4         115.0  348.0         62.746013           2.529863               2
#
#    fabric_thickness  defect_count  elongation_percent  moisture_absorption  \
# 0          0.891865            11           31.299228            12.855777
# 1          0.872380             4            8.092515             7.224689
# 2          1.231906             3           24.134907            12.276679
# 3          0.320100            12           18.334479            14.732114
# 4          0.903725            14            6.396909            11.692512
#
# ...

# %%
df_train , df_test = train_test_split(df,test_size=0.25,random_state=100)

# %%
df_train.to_csv('../data/Industrial Fabric Quality Inspection Dataset - Train.csv',index=False)
df_test.to_csv('../data/Industrial Fabric Quality Inspection Dataset - Test.csv',index=False)

# %%
# %pwd
# Out:
# '/home/legacy/Projects/ML2_Classifiers_and_Streamlit'

# %%
# %run model/LogisticRegression.py
# Out:
# Training size : 18874
# Features : 22
# LogisticRegression trained successfully - ✓
# Model saved - ✓

# %%
# %run model/KNeighborsClassifier.py
# Out:
# Training size : 18874
# Features : 22
# KNeighborsClassifier trained successfully - ✓
# Model saved - ✓

# %%
# %run model/DecisionTreeClassifier.py
# Out:
# Training size : 18874
# Features : 22
# DecisionTreeClassifier trained successfully - ✓
# Model saved - ✓

# %%
# %run model/RandomForestClassifier.py
# Out:
# Training size : 18874
# Features : 22
# RandomForestClassifier trained successfully - ✓
# Model saved - ✓

# %%
# %run model/NaiveBayes.py
# Out:
# Training size : 18874
# Features : 22
# NaiveBayes trained successfully - ✓
# Model saved - ✓

# %%
# %run model/XGBClassifier.py
# Out:
# Training size : 18874
# Features : 22
# XGBClassifier trained successfully - ✓
# Model saved - ✓

# %%
# %pip freeze
# Out:
# altair==4.2.2
# asttokens==3.0.1
# attrs==25.4.0
# blinker==1.9.0
# cachetools==6.2.4
# certifi==2026.1.4
# charset-normalizer==3.4.4
# click==8.3.1
# comm==0.2.3
# contourpy==1.3.3
# cycler==0.12.1
# debugpy==1.8.19
# decorator==5.2.1
# entrypoints==0.4
# executing==2.2.1
# fonttools==4.61.1
# gitdb==4.0.12
# GitPython==3.1.46
# idna==3.11
# ipykernel==7.1.0
# ipython==9.9.0
# ipython_pygments_lexers==1.1.1
# jedi==0.19.2
# Jinja2==3.1.6
# joblib==1.5.3
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter_client==8.8.0
# jupyter_core==5.9.1
# kiwisolver==1.4.9
# MarkupSafe==3.0.3
# matplotlib==3.10.8
# matplotlib-inline==0.2.1
# narwhals==2.15.0
# nest-asyncio==1.6.0
# numpy==2.4.1
# packaging==25.0
# pandas==2.3.3
# parso==0.8.5
# pexpect==4.9.0
# pillow==12.1.0
# platformdirs==4.5.1
# prompt_toolkit==3.0.52
# protobuf==6.33.4
# psutil==7.2.1
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pyarrow==22.0.0
# pydeck==0.9.1
# Pygments==2.19.2
# pyparsing==3.3.1
# ...
